# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas_datareader.data as pdr
import yfinance

yfinance.pdr_override()

# %%
tabela = pd.read_excel('Carteira.xlsx')
display(tabela)
# Out:
#     Ativos  Tipo  Qtde
# 0   BOVA11   ETF   100
# 1   SMAL11   ETF   100
# 2    MGLU3  Ação   100
# 3    BBDC4  Ação   100
# 4    ITUB4  Ação   300
# 5    ENEV3  Ação   100
# 6    MOVI3  Ação   100
# 7   BPAC11  Ação   100
# 8    NTCO3  Ação   100
# 9   BCRI11   FII   100
# 10  VILG11   FII   100
# 11  KNRI11   FII   100
# 12  XPLG11   FII   100

# %%
#criar um grafico de pizza com o valor atual de cada ativo, para saber quanto cada ativo representa do total

ativos = tabela['Ativos']
quantidade = tabela['Qtde']

plt.pie(quantidade, labels=ativos, autopct='%1.1f%%', startangle=90)
plt.title('Distribuição Percentual de Ativos')
plt.show()
